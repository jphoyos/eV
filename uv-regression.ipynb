# %% [markdown]
# # Regression

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import os
os.listdir('/kaggle/input/')
# Out:
# ['datacleaned', 'datasetev']

# %%
csv_file = '../input/datasetev/dataset_fluorite.csv'

# %%
df = pd.read_csv(csv_file, index_col=0)
df
# Out:
#                                                      x  \
# 0    [1.12726309532197, 1.1282891794029504, 1.12931...
# 1    [1.12726309532197, 1.1282891794029504, 1.12931...
# 2    [1.12726309532197, 1.1282891794029504, 1.12931...
# 3    [1.12726309532197, 1.1282891794029504, 1.12931...
# 4    [1.12726309532197, 1.1282891794029504, 1.12931...
# ..                                                 ...
# 525  [1.1272693495638397, 1.1282958218178423, 1.129...
# 526  [1.1272693495638397, 1.1282958218178423, 1.129...
# 527  [1.1272693495638397, 1.1282958218178423, 1.129...
# 528  [1.1272693495638397, 1.1282958218178423, 1.129...
# 529  [1.1272693495638397, 1.1282958218178423, 1.129...
#
#                                                      y  band_gap_mean  \
# 0    [0.0060821480926347695, 0.0037368379172620283,...          5.718
# 1    [0.0029711356613742385, 0.00526027078130591, 0...          4.828
# 2    [0.006912517453482746, 0.0014919367121750456, ...          5.208
# 3    [0.000584220105284513, 0.0012678679192115099, ...          3.376
# 4    [0.02162931471196681, 0.006063456275259739, 0....          2.468
# ..                                                 ...            ...
# 525  [0.017990257672501318, 0.0207421147172066, 0.0...            NaN
# 526  [0.012789468742617965, 0.01073170945579353, 0....            NaN
# 527  [0.006453451706984381, 0.009193232381175842, 0...            NaN
# 528  [0.001983856795892142, 0.005797569886157499, 0...            NaN
# 529  [0.002323162988905185, 0.05241310854277714, 0....            NaN
#
#      band_gap_std
# 0           0.004
# 1           0.011
# 2           0.010
# 3           0.003
# 4           0.038
# ..            ...
# 525           NaN
# 526           NaN
# 527           NaN
# 528           NaN
# 529           NaN
#
# [530 rows x 4 columns]

# %%
df = pd.read_csv('../input/datasetev/fluorite_y.csv', header = None).iloc[0:530,:]
df['band_gap_mean'] = pd.read_csv('../input/datasetev/fluorite_bandgap.csv', header = None)[0]
df['band_gap_std'] = pd.read_csv('../input/datasetev/fluorite_bandgap.csv', header = None)[1]
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.006082  0.003737  0.006728  0.001857  0.002945  0.001538  0.006086
# 1    0.002971  0.005260  0.001771  0.012920  0.000933  0.001629  0.006019
# 2    0.006913  0.001492  0.001884  0.002635  0.012823  0.003563  0.006598
# 3    0.000584  0.001268  0.007138  0.002705  0.005795  0.012183  0.004466
# 4    0.021629  0.006063  0.013065  0.004603  0.002568  0.005661  0.003093
# ..        ...       ...       ...       ...       ...       ...       ...
# 525  0.017990  0.020742  0.016185  0.016691  0.023395  0.023083  0.014904
# 526  0.012789  0.010732  0.005676  0.027419  0.002899  0.009266  0.021219
# 527  0.006453  0.009193  0.005575  0.007479  0.015778  0.004459  0.003519
# 528  0.001984  0.005798  0.008228  0.006638  0.009227  0.007476  0.001910
# 529  0.002323  0.052413  0.022616  0.052204  0.020056  0.023013  0.013422
#
#             7         8         9  ...         893         894         895  \
# 0    0.002238  0.004855  0.002891  ...  107.568905  121.502041  131.770976
# 1    0.005174  0.008844  0.002177  ...  141.128280  156.962763  169.964075
# 2    0.001405  0.006776  0.002198  ...  100.225661  110.839464  121.012922
# 3    0.007690  0.003860  0.001389  ...  106.907550  118.751604  122.912561
# 4    0.001541  0.006786  0.002148  ...  137.423699  149.534100  158.216701
# ..        ...       ...       ...  ...         ...         ...         ...
# 525  0.017298  0.018539  0.002720  ...  186.114637  189.102332  187.735335
# 526  0.008147  0.006809  0.007573  ...  237.485078  245.432425  236.227123
# 527  0.007283  0.005073  0.012451  ...  219.121120  224.962176  222.656578
# 528  0.007732  0.005283  0.008867  ...  183.311117  190.850651  198.854303
# 529  0.005326  0.015300  0.015895  ...  198.970152  209.921612  204.525447
#
#             896         897         898         899         900  \
# 0    141.740017  140.176042  144.377211  143.963082  137.649381
# 1    172.313602  180.557177  181.880892  185.552112  179.537257
# 2    129.086329  130.438964  130.592973  128.548049  124.472706
# 3    131.262604  138.595620  140.545143  139.489657  140.155338
# 4    161.186596  176.674398  178.196450  167.540916  166.755316
# ..          ...         ...         ...         ...         ...
# 525  215.315820  213.815831  221.290957  211.468605  213.675886
# 526  271.570559  269.617692  278.820317  269.375275  273.074854
# 527  256.972817  252.927983  261.145384  247.587132  245.955216
# 528  216.403308  221.843636  210.234578  208.092593  201.378322
# 529  235.613130  230.740794  229.041485  236.651288  216.312667
#
#      band_gap_mean  band_gap_std
# 0            5.718         0.004
# 1            4.828         0.011
# 2            5.208         0.010
# 3            3.376         0.003
# 4            2.468         0.038
# ..             ...           ...
# 525            NaN           NaN
# 526            NaN           NaN
# 527            NaN           NaN
# 528            NaN           NaN
# 529            NaN           NaN
#
# [530 rows x 903 columns]

# %% [markdown]
# ## Upsampling

# %%
up_sampling = 5

# %%
df['band_gap_mean'] = np.repeat(df['band_gap_mean'].dropna().to_numpy(),up_sampling)
df['band_gap_std'] = np.repeat(df['band_gap_std'].dropna().to_numpy(),up_sampling)
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.006082  0.003737  0.006728  0.001857  0.002945  0.001538  0.006086
# 1    0.002971  0.005260  0.001771  0.012920  0.000933  0.001629  0.006019
# 2    0.006913  0.001492  0.001884  0.002635  0.012823  0.003563  0.006598
# 3    0.000584  0.001268  0.007138  0.002705  0.005795  0.012183  0.004466
# 4    0.021629  0.006063  0.013065  0.004603  0.002568  0.005661  0.003093
# ..        ...       ...       ...       ...       ...       ...       ...
# 525  0.017990  0.020742  0.016185  0.016691  0.023395  0.023083  0.014904
# 526  0.012789  0.010732  0.005676  0.027419  0.002899  0.009266  0.021219
# 527  0.006453  0.009193  0.005575  0.007479  0.015778  0.004459  0.003519
# 528  0.001984  0.005798  0.008228  0.006638  0.009227  0.007476  0.001910
# 529  0.002323  0.052413  0.022616  0.052204  0.020056  0.023013  0.013422
#
#             7         8         9  ...         893         894         895  \
# 0    0.002238  0.004855  0.002891  ...  107.568905  121.502041  131.770976
# 1    0.005174  0.008844  0.002177  ...  141.128280  156.962763  169.964075
# 2    0.001405  0.006776  0.002198  ...  100.225661  110.839464  121.012922
# 3    0.007690  0.003860  0.001389  ...  106.907550  118.751604  122.912561
# 4    0.001541  0.006786  0.002148  ...  137.423699  149.534100  158.216701
# ..        ...       ...       ...  ...         ...         ...         ...
# 525  0.017298  0.018539  0.002720  ...  186.114637  189.102332  187.735335
# 526  0.008147  0.006809  0.007573  ...  237.485078  245.432425  236.227123
# 527  0.007283  0.005073  0.012451  ...  219.121120  224.962176  222.656578
# 528  0.007732  0.005283  0.008867  ...  183.311117  190.850651  198.854303
# 529  0.005326  0.015300  0.015895  ...  198.970152  209.921612  204.525447
#
#             896         897         898         899         900  \
# 0    141.740017  140.176042  144.377211  143.963082  137.649381
# 1    172.313602  180.557177  181.880892  185.552112  179.537257
# 2    129.086329  130.438964  130.592973  128.548049  124.472706
# 3    131.262604  138.595620  140.545143  139.489657  140.155338
# 4    161.186596  176.674398  178.196450  167.540916  166.755316
# ..          ...         ...         ...         ...         ...
# 525  215.315820  213.815831  221.290957  211.468605  213.675886
# 526  271.570559  269.617692  278.820317  269.375275  273.074854
# 527  256.972817  252.927983  261.145384  247.587132  245.955216
# 528  216.403308  221.843636  210.234578  208.092593  201.378322
# 529  235.613130  230.740794  229.041485  236.651288  216.312667
#
#      band_gap_mean  band_gap_std
# 0            5.718         0.004
# 1            5.718         0.004
# 2            5.718         0.004
# 3            5.718         0.004
# 4            5.718         0.004
# ..             ...           ...
# 525          2.069         0.026
# 526          2.069         0.026
# 527          2.069         0.026
# 528          2.069         0.026
# 529          2.069         0.026
#
# [530 rows x 903 columns]

# %% [markdown]
# ## IDEA
# Realizar una comparacion del desempeño con dos y tres cifras decimales

# %%
#Round to two decimal digits
df['band_gap_mean'] = df['band_gap_mean'].round(2)
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.006082  0.003737  0.006728  0.001857  0.002945  0.001538  0.006086
# 1    0.002971  0.005260  0.001771  0.012920  0.000933  0.001629  0.006019
# 2    0.006913  0.001492  0.001884  0.002635  0.012823  0.003563  0.006598
# 3    0.000584  0.001268  0.007138  0.002705  0.005795  0.012183  0.004466
# 4    0.021629  0.006063  0.013065  0.004603  0.002568  0.005661  0.003093
# ..        ...       ...       ...       ...       ...       ...       ...
# 525  0.017990  0.020742  0.016185  0.016691  0.023395  0.023083  0.014904
# 526  0.012789  0.010732  0.005676  0.027419  0.002899  0.009266  0.021219
# 527  0.006453  0.009193  0.005575  0.007479  0.015778  0.004459  0.003519
# 528  0.001984  0.005798  0.008228  0.006638  0.009227  0.007476  0.001910
# 529  0.002323  0.052413  0.022616  0.052204  0.020056  0.023013  0.013422
#
#             7         8         9  ...         893         894         895  \
# 0    0.002238  0.004855  0.002891  ...  107.568905  121.502041  131.770976
# 1    0.005174  0.008844  0.002177  ...  141.128280  156.962763  169.964075
# 2    0.001405  0.006776  0.002198  ...  100.225661  110.839464  121.012922
# 3    0.007690  0.003860  0.001389  ...  106.907550  118.751604  122.912561
# 4    0.001541  0.006786  0.002148  ...  137.423699  149.534100  158.216701
# ..        ...       ...       ...  ...         ...         ...         ...
# 525  0.017298  0.018539  0.002720  ...  186.114637  189.102332  187.735335
# 526  0.008147  0.006809  0.007573  ...  237.485078  245.432425  236.227123
# 527  0.007283  0.005073  0.012451  ...  219.121120  224.962176  222.656578
# 528  0.007732  0.005283  0.008867  ...  183.311117  190.850651  198.854303
# 529  0.005326  0.015300  0.015895  ...  198.970152  209.921612  204.525447
#
#             896         897         898         899         900  \
# 0    141.740017  140.176042  144.377211  143.963082  137.649381
# 1    172.313602  180.557177  181.880892  185.552112  179.537257
# 2    129.086329  130.438964  130.592973  128.548049  124.472706
# 3    131.262604  138.595620  140.545143  139.489657  140.155338
# 4    161.186596  176.674398  178.196450  167.540916  166.755316
# ..          ...         ...         ...         ...         ...
# 525  215.315820  213.815831  221.290957  211.468605  213.675886
# 526  271.570559  269.617692  278.820317  269.375275  273.074854
# 527  256.972817  252.927983  261.145384  247.587132  245.955216
# 528  216.403308  221.843636  210.234578  208.092593  201.378322
# 529  235.613130  230.740794  229.041485  236.651288  216.312667
#
#      band_gap_mean  band_gap_std
# 0             5.72         0.004
# 1             5.72         0.004
# 2             5.72         0.004
# 3             5.72         0.004
# 4             5.72         0.004
# ..             ...           ...
# 525           2.07         0.026
# 526           2.07         0.026
# 527           2.07         0.026
# 528           2.07         0.026
# 529           2.07         0.026
#
# [530 rows x 903 columns]

# %%
from sklearn.linear_model import *
import sklearn.ensemble
import sklearn.neighbors
import sklearn.neural_network
from xgboost import XGBRegressor
#ExtraTreesRegressor
#GradientBoostingRegressor
#StackingRegressor

models = [(sklearn.ensemble.RandomForestRegressor(),
           {
               'boostrap': [True, False],
              'max_depth':[10,20,50],
              'max_features':['auto','sqrt']
           },
           sklearn.neighbors.KNeighborsRegressor(),
           {
               'n_neighbors': [5, 10, 15, 20],
                'weights': ['uniform', 'distance']
           },
           XGBRegressor(),
           {
               'n_estimators': [100,300],
               'learning_rate': [0.1,0.05],
               'subsample': [0.75],
               'colsample_bytree': [1],
               'max_depth': [3,4,5],
               'gamma': [0]
           }
          )
        ]

models_ = [sklearn.ensemble.RandomForestRegressor(),
           sklearn.ensemble.AdaBoostRegressor(),
           sklearn.ensemble.BaggingRegressor(),
           sklearn.ensemble.ExtraTreesRegressor(),
           sklearn.ensemble.HistGradientBoostingRegressor(),#  LightGBM
           sklearn.ensemble.ExtraTreesRegressor(),
           XGBRegressor(n_jobs = -1),
           sklearn.neighbors.KNeighborsRegressor(),
           sklearn.linear_model.ARDRegression(),
           sklearn.linear_model.ElasticNetCV(),             #Include Cross-Validation
           sklearn.linear_model.BayesianRidge(),
           sklearn.linear_model.SGDRegressor(max_iter=5000, tol=1e-3),
           sklearn.linear_model.ElasticNet(),
           sklearn.neural_network.MLPRegressor(hidden_layer_sizes=(901,64,64))]

# %%
import sklearn.model_selection
import sklearn.metrics
import json
import joblib

class Encoder(json.JSONEncoder):
    def default(self, obj): # pylint: disable=E0202
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, sklearn.tree.DecisionTreeClassifier):
            return obj.__class__.__name__
        else:
            return super(Encoder, self).default(obj)
        
class Splitter:
    def __init__(self,data, label = "band_gap_mean"):
        self.data  = data
        self.features = self.data.iloc[:,:-2]
        self.label = self.data[label]
        self.data = None     
    def split(self, location):
        self.features_train, self.features_test, self.label_train, self.label_test = sklearn.model_selection.train_test_split(self.features, self.label, test_size=0.3 )
        self.features_train.to_csv(location + 'features_train.csv', index = False)
        self.features_test.to_csv(location + 'features_test.csv', index = False, header = True)
        self.label_train.to_csv(location + 'label_train.csv', index = False)
        self.label_test.to_csv(location + 'label_test.csv', index = False, header = True)
        
class EvModelDev:
    def __init__(self, features_train, label_train, models):
        self.features_train = pd.read_csv(features_train)
        self.label_train = pd.read_csv(label_train)
        self.train = np.concatenate([self.features_train, self.label_train], axis=1) #to speed up the training we convert it to numpy
        self.models = models
    def grid_search(self,report_location, n_jobs=8, models = models, scoring = 'geometric_mean' ):
        self.gs_scores = {}
        for model in models:
            nomdel_name = model[0].__class__.__name__
            estimator = model[0]
            grid = model[1]
            features = self.train[:,:-1]
            label = self.train[:,-1]
            if scoring == 'neg_mean_absolute_percentage_error':
                scorer = sklearn.metrics.mean_absolute_percentage_error
            grid_search = sklearn.model_selection.RandomizedSearchCV(
            estimator=estimator,
            param_distributions=grid,
            scoring=scorer,
            n_jobs=n_jobs,
            verbose=2,
            random_state=11,
            return_train_score=True,
            cv=3
            )
            grid_search.fit(features, label)
            self.gs_scores[model_name] = [grid_search.cv_results_, grid_search.best_params_, grid_search.best_score_]
            with open(report_location + 'grid_search_'+ model_name + '.json', 'w', encoding='utf-8') as json_file:
                     json.dump(self.gs_scores[model_name], json_file, indent=2, ensure_ascii=False, cls=Encoder)
    def train_cv(self, models_locatiion, report_location, n_jobs=8):
        self.cv_scores={}
        features = self.train[:,:-1]
        label = self.train[:,-1]
        for model in self.models:
            model_name = model.__class__.__name__
            estimator = model
            cv_scores = sklearn.model_selection.cross_validate(
                estimator=estimator,
                X=features,
                y=label,
                cv=5,
                n_jobs=n_jobs,
                scoring={
                    'mean_absolute_error':'neg_mean_absolute_error',
                    'mean_absolute_percentage_error':'neg_mean_absolute_percentage_error',
                    'mean_squared_error':'neg_mean_squared_error',
                    'r2':'r2',
                    'explained_variance':'explained_variance'
                },                                                   #sklearn.metrics.SCORERS.keys()
                verbose=2,
                return_train_score=True
            )
            self.cv_scores[model_name] = cv_scores
            with open(report_location + 'cross_val_' + model_name + '.json', 'w', encoding = 'utf-8') as json_file:
                json.dump(self.cv_scores[model_name], json_file, indent=2, ensure_ascii=False, cls=Encoder)
    def train_direct(self, model_location):
        for estimator in self.models:
            model_name = estimator.__class__.__name__
            print(model_name)
            features = self.train[:,:-1]
            label  = self.train[:,-1]
            estimator.fit(features, label)
            print(estimator.score(features,label))
            joblib.dump(estimator, model_location + model_name + ".joblib")
    def predict_direct(self, models_location, features_test, label_test):
        features_test = pd.read_csv(features_test)
        label_test = pd.read_csv(label_test)
        for model in self.models:
            model_name = model.__class__.__name__
            estimator = joblib.load(models_location + model_name + '.joblib')
            try:
                bg_predict = estimator.predict(features_test.values)
            except:
                bg_predict = np.zeros(len(label_test),1)
            results = np.column_stack([label_test,bg_predict])
            np.savetxt(models_location + model_name + '_predictions.txt',results)

class EvalModel:
    def __init__(self, models):
        self.models = models
    def performance(self, models_location):
        for model in self.models:    #se debe crear un json que guarde todos los datos
            model_name = model.__class__.__name__
            results = np.loadtxt(models_location+ model_name + '_predictions.txt')
            mae = sklearn.metrics.mean_absolute_error(results[:,0],results[:,1].round(2))  #TWO decimal digits
            mape = sklearn.metrics.mean_absolute_percentage_error(results[:,0],results[:,1].round(2))
            mse = sklearn.metrics.mean_squared_error(results[:,0],results[:,1].round(2))
            r2 = sklearn.metrics.r2_score(results[:,0],results[:,1].round(2))
            print('Model: ', model_name)
            print('MAE: ', mae)
            print('\nMAPE: ', mape)
            print('\nMSE: ', mse)
            print('\nR2: ', r2)

# %%
s = Splitter(df)
s.split("/kaggle/working/")

# %%
m = EvModelDev("/kaggle/working/features_train.csv", "/kaggle/working/label_train.csv", models_)
m.train_cv("/kaggle/working/", "/kaggle/working/", n_jobs=4)
m.train_direct("/kaggle/working/")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:   26.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:    2.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:    2.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:    8.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:   11.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:    8.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:   11.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:   22.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.908e-02, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.503e-02, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.961e-02, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.909e-02, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.443e-02, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.265e-02, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.005e-02, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.312e-02, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.145e-02, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.724e-02, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.794e-01, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.311e-01, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.924e-01, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.625e-01, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.328e-01, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.754e-01, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.865e-01, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.006e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.283e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.388e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.809e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.091e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.927e-02, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.080e-02, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.104e-02, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.742e-02, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.062e-02, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.447e-01, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.725e-01, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.288e-01, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.224e-01, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.203e-01, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.258e-01, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.300e-01, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.133e-01, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.797e-01, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.298e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.665e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.778e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.527e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.733e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.729e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.743e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.719e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.404e-02, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.533e-02, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.567e-02, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.776e-02, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.812e-02, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.783e-02, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.451e-02, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.267e-01, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.606e-01, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.840e-01, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.197e-01, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.522e-01, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.269e-01, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.203e-01, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.685e-01, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.850e-01, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.496e-01, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.237e-01, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.055e+00, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.038e+00, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.164e+00, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.243e+00, tolerance: 1.516e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.014e-02, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.101e-02, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.146e-02, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.183e-02, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.707e-02, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.336e-02, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.157e-02, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.560e-02, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.176e-01, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.497e-01, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.978e-01, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.522e-01, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.313e-01, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.154e-01, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.619e-01, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.660e-01, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.012e+00, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.022e+00, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.883e-01, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.629e-01, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.007e-01, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.077e+00, tolerance: 1.627e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.278e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.229e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.457e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.596e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.743e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.769e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.982e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.023e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.292e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.604e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.894e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.730e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.841e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.334e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.350e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.469e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.620e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.963e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.365e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.513e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.459e+00, tolerance: 1.403e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.745e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.899e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.296e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.916e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.365e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.612e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.679e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.841e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.997e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.147e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.433e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.892e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.239e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.347e+00, tolerance: 1.320e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.585e+00, tolerance: 1.320e-02
# ...
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.765e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.188e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.565e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.862e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.251e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.164e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.227e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.441e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.530e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.683e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.676e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.873e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.042e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.427e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.698e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.793e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.529e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.400e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.331e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.510e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.197e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.550e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.955e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.227e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.791e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.605e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.480e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.902e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.585e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.115e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.395e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.735e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.803e+00, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.013e+01, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.019e+01, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.020e+01, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.047e+01, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.095e+01, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.141e+01, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.157e+01, tolerance: 2.270e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.944e+01, tolerance: 2.571e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# 0.6387530646266675
# BayesianRidge
# 0.8547444481553911
# SGDRegressor
# -1.9107403803099573e+33
# ElasticNet
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.186e+01, tolerance: 2.571e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# 0.6430286732731779
# MLPRegressor
# -3.8531602652070776

# %%
m.predict_direct("/kaggle/working/","/kaggle/working/features_test.csv","/kaggle/working/label_test.csv")

# %%
#Data with three decimal digits
#MAE:  0.057852893081761246
#MSE:  0.021104927610691843

e = EvalModel(models_)
e.performance("/kaggle/working/")
# Out:
# Model:  RandomForestRegressor
# MAE:  0.04314465408805032
#
# MAPE:  0.019309490623235847
#
# MSE:  0.003633962264150947
#
# R2:  0.9930998223773317
# Model:  AdaBoostRegressor
# MAE:  0.0571698113207547
#
# MAPE:  0.02581775564439282
#
# MSE:  0.007232075471698117
#
# R2:  0.9862677150427375
# Model:  BaggingRegressor
# MAE:  0.051823899371069196
#
# MAPE:  0.023166890225102744
#
# MSE:  0.006784905660377364
#
# R2:  0.9871168023202933
# Model:  ExtraTreesRegressor
# MAE:  0.037672955974842784
#
# MAPE:  0.017253948359740513
#
# MSE:  0.003144025157232708
#
# R2:  0.9940301163143442
# Model:  HistGradientBoostingRegressor
# MAE:  0.06880503144654086
#
# MAPE:  0.02793586559809915
#
# MSE:  0.027205031446540868
#
# R2:  0.9483430108608274
# Model:  ExtraTreesRegressor
# MAE:  0.037672955974842784
#
# MAPE:  0.017253948359740513
#
# MSE:  0.003144025157232708
#
# R2:  0.9940301163143442
# Model:  XGBRegressor
# MAE:  0.06465408805031447
#
# MAPE:  0.026757305731690596
#
# MSE:  0.029184905660377358
#
# R2:  0.9445836202142093
# Model:  KNeighborsRegressor
# MAE:  0.09559748427672954
#
# MAPE:  0.038551885939991225
#
# MSE:  0.03021006289308177
#
# R2:  0.9426370488184063
# Model:  ARDRegression
# MAE:  3.262201257861635
#
# MAPE:  1.3558417749523899
#
# MSE:  373.83226352201245
#
# R2:  -708.8337384603284
# Model:  ElasticNetCV
# MAE:  0.41698113207547177
#
# MAPE:  0.17779533131277359
#
# MSE:  0.44974968553459116
#
# R2:  0.14601405013407143
# Model:  BayesianRidge
# MAE:  0.42974842767295607
#
# MAPE:  0.17857557092120183
#
# MSE:  0.8297981132075473
#
# R2:  -0.5756229580509622
# Model:  SGDRegressor
# MAE:  1.6466943993656606e+16
#
# MAPE:  6810985084644936.0
#
# MSE:  2.250732463414366e+33
#
# R2:  -4.2736970418963567e+33
# Model:  ElasticNet
# MAE:  0.42157232704402514
#
# MAPE:  0.17808981836101254
#
# MSE:  0.4585188679245283
#
# R2:  0.12936310229868475
# Model:  MLPRegressor
# MAE:  1.4304402515723271
#
# MAPE:  0.6116310734514487
#
# MSE:  4.253343396226415
#
# R2:  -7.076260233545005

# %%
#Resultados
np.loadtxt('/kaggle/working/RandomForestRegressor_predictions.txt').round(2)
# Out:
# array([[2.03, 2.02],
#        [2.22, 2.04],
#        [2.08, 1.99],
#        [2.27, 2.06],
#        [2.12, 2.06],
#        [1.86, 1.89],
#        [1.94, 2.  ],
#        [5.01, 5.05],
#        [2.06, 2.05],
#        [2.05, 2.07],
#        [2.14, 2.12],
#        [1.97, 1.99],
#        [2.04, 2.13],
#        [2.03, 2.05],
#        [1.92, 1.97],
#        [3.29, 3.3 ],
#        [1.99, 1.97],
#        [3.35, 3.31],
#        [2.01, 2.01],
#        [1.98, 2.02],
#        [2.02, 2.02],
#        [2.15, 2.15],
#        [2.47, 2.34],
#        [4.84, 4.85],
#        [3.23, 3.26],
#        [4.84, 4.75],
#        [2.04, 1.97],
#        [1.99, 2.02],
#        [2.05, 2.09],
#        [1.94, 1.99],
#        [2.  , 2.06],
#        [1.98, 2.01],
#        [1.94, 1.98],
#        [2.02, 2.04],
#        [5.72, 5.53],
#        [2.01, 2.01],
#        [1.97, 1.98],
#        [2.1 , 2.22],
#        [2.06, 2.02],
#        [2.24, 2.23],
#        [2.05, 2.12],
#        [2.  , 2.02],
#        [2.03, 2.05],
#        [3.3 , 3.32],
#        [1.99, 2.01],
#        [3.38, 3.33],
#        [2.03, 2.17],
#        [2.02, 2.05],
#        [2.06, 2.04],
#        [3.38, 3.33],
#        [2.08, 1.98],
#        [2.15, 2.12],
#        [2.07, 2.12],
#        [2.22, 2.11],
#        [2.02, 2.02],
#        [2.07, 2.03],
#        [2.07, 2.14],
#        [2.07, 2.05],
#        [2.15, 2.06],
#        [2.07, 2.04],
#        [2.04, 2.03],
#        [2.07, 2.13],
#        [2.07, 2.07],
#        [2.04, 2.09],
#        [2.03, 2.01],
#        [2.02, 2.08],
#        [2.07, 2.12],
#        [1.98, 2.  ],
#        [2.16, 2.18],
#        [2.02, 1.99],
#        [1.97, 1.98],
#        [2.26, 2.2 ],
#        [1.94, 1.98],
#        [5.21, 5.18],
#        [2.05, 2.24],
#        [1.92, 1.99],
#        [1.97, 1.98],
#        [4.83, 4.85],
#        [2.02, 2.02],
#        [1.86, 1.91],
#        [2.02, 2.01],
#        [1.97, 1.97],
#        [2.05, 2.14],
#        [2.21, 2.32],
#        [2.07, 2.14],
#        [2.11, 2.12],
#        [2.06, 2.06],
#        [3.31, 3.31],
#        [2.07, 2.12],
#        [2.08, 2.16],
#        [3.23, 3.25],
#        [2.05, 2.13],
#        [2.14, 2.1 ],
#        [2.02, 2.02],
#        [2.  , 2.03],
#        [3.29, 3.31],
#        [2.05, 2.13],
#        [2.26, 2.17],
#        [2.24, 2.28],
#        [2.47, 2.36],
#        [2.04, 2.06],
#        [3.38, 3.34],
#        [2.11, 2.11],
#        [2.1 , 2.18],
#        [1.99, 2.01],
#        [2.15, 2.16],
#        [3.29, 3.31],
#        [2.02, 2.05],
#        [1.92, 2.  ],
#        [1.97, 1.97],
#        [2.12, 2.11],
#        [2.08, 1.99],
#        [2.08, 2.14],
#        [2.01, 1.99],
#        [2.06, 2.03],
#        [2.07, 2.12],
#        [2.27, 2.06],
#        [4.84, 4.9 ],
#        [2.07, 2.12],
#        [2.07, 2.06],
#        [2.22, 2.1 ],
#        [2.25, 2.22],
#        [1.97, 1.98],
#        [3.3 , 3.31],
#        [2.04, 2.07],
#        [2.  , 2.02],
#        [2.03, 2.03],
#        [2.07, 2.14],
#        [2.15, 2.06],
#        [3.35, 3.33],
#        [2.21, 2.22],
#        [2.15, 2.13],
#        [2.07, 2.12],
#        [2.  , 2.  ],
#        [2.04, 1.98],
#        [2.01, 2.  ],
#        [2.47, 2.34],
#        [2.14, 2.18],
#        [2.03, 2.04],
#        [1.98, 2.02],
#        [4.98, 5.02],
#        [1.99, 2.01],
#        [3.3 , 3.32],
#        [2.15, 2.14],
#        [1.84, 1.93],
#        [1.98, 2.02],
#        [2.04, 2.04],
#        [2.03, 2.02],
#        [2.09, 2.05],
#        [2.04, 2.04],
#        [2.07, 2.05],
#        [2.26, 2.21],
#        [2.01, 2.01],
#        [1.94, 1.99],
#        [2.12, 2.1 ],
#        [2.12, 2.08],
#        [1.98, 2.01],
#        [2.15, 2.15],
#        [2.06, 2.08]])
