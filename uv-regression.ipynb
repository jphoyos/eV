# %% [markdown]
# # Regression

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import os
os.listdir('/kaggle/input/')
# Out:
# ['datasetev', 'datacleaned']

# %%
csv_file = '../input/datasetev/dataset_fluorite.csv'

# %%
df = pd.read_csv(csv_file, index_col=0)
df
# Out:
#                                                      x  \
# 0    [1.12726309532197, 1.1282891794029504, 1.12931...
# 1    [1.12726309532197, 1.1282891794029504, 1.12931...
# 2    [1.12726309532197, 1.1282891794029504, 1.12931...
# 3    [1.12726309532197, 1.1282891794029504, 1.12931...
# 4    [1.12726309532197, 1.1282891794029504, 1.12931...
# ..                                                 ...
# 525  [1.1272693495638397, 1.1282958218178423, 1.129...
# 526  [1.1272693495638397, 1.1282958218178423, 1.129...
# 527  [1.1272693495638397, 1.1282958218178423, 1.129...
# 528  [1.1272693495638397, 1.1282958218178423, 1.129...
# 529  [1.1272693495638397, 1.1282958218178423, 1.129...
#
#                                                      y  band_gap_mean  \
# 0    [0.0060821480926347695, 0.0037368379172620283,...          5.718
# 1    [0.0029711356613742385, 0.00526027078130591, 0...          4.828
# 2    [0.006912517453482746, 0.0014919367121750456, ...          5.208
# 3    [0.000584220105284513, 0.0012678679192115099, ...          3.376
# 4    [0.02162931471196681, 0.006063456275259739, 0....          2.468
# ..                                                 ...            ...
# 525  [0.017990257672501318, 0.0207421147172066, 0.0...            NaN
# 526  [0.012789468742617965, 0.01073170945579353, 0....            NaN
# 527  [0.006453451706984381, 0.009193232381175842, 0...            NaN
# 528  [0.001983856795892142, 0.005797569886157499, 0...            NaN
# 529  [0.002323162988905185, 0.05241310854277714, 0....            NaN
#
#      band_gap_std
# 0           0.004
# 1           0.011
# 2           0.010
# 3           0.003
# 4           0.038
# ..            ...
# 525           NaN
# 526           NaN
# 527           NaN
# 528           NaN
# 529           NaN
#
# [530 rows x 4 columns]

# %%
df = pd.read_csv('../input/datasetev/fluorite_y.csv', header = None).iloc[0:530,:]
df['band_gap_mean'] = pd.read_csv('../input/datasetev/fluorite_bandgap.csv', header = None)[0]
df['band_gap_std'] = pd.read_csv('../input/datasetev/fluorite_bandgap.csv', header = None)[1]
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.006082  0.003737  0.006728  0.001857  0.002945  0.001538  0.006086
# 1    0.002971  0.005260  0.001771  0.012920  0.000933  0.001629  0.006019
# 2    0.006913  0.001492  0.001884  0.002635  0.012823  0.003563  0.006598
# 3    0.000584  0.001268  0.007138  0.002705  0.005795  0.012183  0.004466
# 4    0.021629  0.006063  0.013065  0.004603  0.002568  0.005661  0.003093
# ..        ...       ...       ...       ...       ...       ...       ...
# 525  0.017990  0.020742  0.016185  0.016691  0.023395  0.023083  0.014904
# 526  0.012789  0.010732  0.005676  0.027419  0.002899  0.009266  0.021219
# 527  0.006453  0.009193  0.005575  0.007479  0.015778  0.004459  0.003519
# 528  0.001984  0.005798  0.008228  0.006638  0.009227  0.007476  0.001910
# 529  0.002323  0.052413  0.022616  0.052204  0.020056  0.023013  0.013422
#
#             7         8         9  ...         893         894         895  \
# 0    0.002238  0.004855  0.002891  ...  107.568905  121.502041  131.770976
# 1    0.005174  0.008844  0.002177  ...  141.128280  156.962763  169.964075
# 2    0.001405  0.006776  0.002198  ...  100.225661  110.839464  121.012922
# 3    0.007690  0.003860  0.001389  ...  106.907550  118.751604  122.912561
# 4    0.001541  0.006786  0.002148  ...  137.423699  149.534100  158.216701
# ..        ...       ...       ...  ...         ...         ...         ...
# 525  0.017298  0.018539  0.002720  ...  186.114637  189.102332  187.735335
# 526  0.008147  0.006809  0.007573  ...  237.485078  245.432425  236.227123
# 527  0.007283  0.005073  0.012451  ...  219.121120  224.962176  222.656578
# 528  0.007732  0.005283  0.008867  ...  183.311117  190.850651  198.854303
# 529  0.005326  0.015300  0.015895  ...  198.970152  209.921612  204.525447
#
#             896         897         898         899         900  \
# 0    141.740017  140.176042  144.377211  143.963082  137.649381
# 1    172.313602  180.557177  181.880892  185.552112  179.537257
# 2    129.086329  130.438964  130.592973  128.548049  124.472706
# 3    131.262604  138.595620  140.545143  139.489657  140.155338
# 4    161.186596  176.674398  178.196450  167.540916  166.755316
# ..          ...         ...         ...         ...         ...
# 525  215.315820  213.815831  221.290957  211.468605  213.675886
# 526  271.570559  269.617692  278.820317  269.375275  273.074854
# 527  256.972817  252.927983  261.145384  247.587132  245.955216
# 528  216.403308  221.843636  210.234578  208.092593  201.378322
# 529  235.613130  230.740794  229.041485  236.651288  216.312667
#
#      band_gap_mean  band_gap_std
# 0            5.718         0.004
# 1            4.828         0.011
# 2            5.208         0.010
# 3            3.376         0.003
# 4            2.468         0.038
# ..             ...           ...
# 525            NaN           NaN
# 526            NaN           NaN
# 527            NaN           NaN
# 528            NaN           NaN
# 529            NaN           NaN
#
# [530 rows x 903 columns]

# %% [markdown]
# ## Upsampling

# %%
up_sampling = 5

# %%
df['band_gap_mean'] = np.repeat(df['band_gap_mean'].dropna().to_numpy(),up_sampling)
df['band_gap_std'] = np.repeat(df['band_gap_std'].dropna().to_numpy(),up_sampling)
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.006082  0.003737  0.006728  0.001857  0.002945  0.001538  0.006086
# 1    0.002971  0.005260  0.001771  0.012920  0.000933  0.001629  0.006019
# 2    0.006913  0.001492  0.001884  0.002635  0.012823  0.003563  0.006598
# 3    0.000584  0.001268  0.007138  0.002705  0.005795  0.012183  0.004466
# 4    0.021629  0.006063  0.013065  0.004603  0.002568  0.005661  0.003093
# ..        ...       ...       ...       ...       ...       ...       ...
# 525  0.017990  0.020742  0.016185  0.016691  0.023395  0.023083  0.014904
# 526  0.012789  0.010732  0.005676  0.027419  0.002899  0.009266  0.021219
# 527  0.006453  0.009193  0.005575  0.007479  0.015778  0.004459  0.003519
# 528  0.001984  0.005798  0.008228  0.006638  0.009227  0.007476  0.001910
# 529  0.002323  0.052413  0.022616  0.052204  0.020056  0.023013  0.013422
#
#             7         8         9  ...         893         894         895  \
# 0    0.002238  0.004855  0.002891  ...  107.568905  121.502041  131.770976
# 1    0.005174  0.008844  0.002177  ...  141.128280  156.962763  169.964075
# 2    0.001405  0.006776  0.002198  ...  100.225661  110.839464  121.012922
# 3    0.007690  0.003860  0.001389  ...  106.907550  118.751604  122.912561
# 4    0.001541  0.006786  0.002148  ...  137.423699  149.534100  158.216701
# ..        ...       ...       ...  ...         ...         ...         ...
# 525  0.017298  0.018539  0.002720  ...  186.114637  189.102332  187.735335
# 526  0.008147  0.006809  0.007573  ...  237.485078  245.432425  236.227123
# 527  0.007283  0.005073  0.012451  ...  219.121120  224.962176  222.656578
# 528  0.007732  0.005283  0.008867  ...  183.311117  190.850651  198.854303
# 529  0.005326  0.015300  0.015895  ...  198.970152  209.921612  204.525447
#
#             896         897         898         899         900  \
# 0    141.740017  140.176042  144.377211  143.963082  137.649381
# 1    172.313602  180.557177  181.880892  185.552112  179.537257
# 2    129.086329  130.438964  130.592973  128.548049  124.472706
# 3    131.262604  138.595620  140.545143  139.489657  140.155338
# 4    161.186596  176.674398  178.196450  167.540916  166.755316
# ..          ...         ...         ...         ...         ...
# 525  215.315820  213.815831  221.290957  211.468605  213.675886
# 526  271.570559  269.617692  278.820317  269.375275  273.074854
# 527  256.972817  252.927983  261.145384  247.587132  245.955216
# 528  216.403308  221.843636  210.234578  208.092593  201.378322
# 529  235.613130  230.740794  229.041485  236.651288  216.312667
#
#      band_gap_mean  band_gap_std
# 0            5.718         0.004
# 1            5.718         0.004
# 2            5.718         0.004
# 3            5.718         0.004
# 4            5.718         0.004
# ..             ...           ...
# 525          2.069         0.026
# 526          2.069         0.026
# 527          2.069         0.026
# 528          2.069         0.026
# 529          2.069         0.026
#
# [530 rows x 903 columns]

# %% [markdown]
# ## IDEA
# Realizar una comparacion del desempeño con dos y tres cifras decimales

# %%
#Round to two decimal digits
df['band_gap_mean'] = df['band_gap_mean'].round(2)
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.006082  0.003737  0.006728  0.001857  0.002945  0.001538  0.006086
# 1    0.002971  0.005260  0.001771  0.012920  0.000933  0.001629  0.006019
# 2    0.006913  0.001492  0.001884  0.002635  0.012823  0.003563  0.006598
# 3    0.000584  0.001268  0.007138  0.002705  0.005795  0.012183  0.004466
# 4    0.021629  0.006063  0.013065  0.004603  0.002568  0.005661  0.003093
# ..        ...       ...       ...       ...       ...       ...       ...
# 525  0.017990  0.020742  0.016185  0.016691  0.023395  0.023083  0.014904
# 526  0.012789  0.010732  0.005676  0.027419  0.002899  0.009266  0.021219
# 527  0.006453  0.009193  0.005575  0.007479  0.015778  0.004459  0.003519
# 528  0.001984  0.005798  0.008228  0.006638  0.009227  0.007476  0.001910
# 529  0.002323  0.052413  0.022616  0.052204  0.020056  0.023013  0.013422
#
#             7         8         9  ...         893         894         895  \
# 0    0.002238  0.004855  0.002891  ...  107.568905  121.502041  131.770976
# 1    0.005174  0.008844  0.002177  ...  141.128280  156.962763  169.964075
# 2    0.001405  0.006776  0.002198  ...  100.225661  110.839464  121.012922
# 3    0.007690  0.003860  0.001389  ...  106.907550  118.751604  122.912561
# 4    0.001541  0.006786  0.002148  ...  137.423699  149.534100  158.216701
# ..        ...       ...       ...  ...         ...         ...         ...
# 525  0.017298  0.018539  0.002720  ...  186.114637  189.102332  187.735335
# 526  0.008147  0.006809  0.007573  ...  237.485078  245.432425  236.227123
# 527  0.007283  0.005073  0.012451  ...  219.121120  224.962176  222.656578
# 528  0.007732  0.005283  0.008867  ...  183.311117  190.850651  198.854303
# 529  0.005326  0.015300  0.015895  ...  198.970152  209.921612  204.525447
#
#             896         897         898         899         900  \
# 0    141.740017  140.176042  144.377211  143.963082  137.649381
# 1    172.313602  180.557177  181.880892  185.552112  179.537257
# 2    129.086329  130.438964  130.592973  128.548049  124.472706
# 3    131.262604  138.595620  140.545143  139.489657  140.155338
# 4    161.186596  176.674398  178.196450  167.540916  166.755316
# ..          ...         ...         ...         ...         ...
# 525  215.315820  213.815831  221.290957  211.468605  213.675886
# 526  271.570559  269.617692  278.820317  269.375275  273.074854
# 527  256.972817  252.927983  261.145384  247.587132  245.955216
# 528  216.403308  221.843636  210.234578  208.092593  201.378322
# 529  235.613130  230.740794  229.041485  236.651288  216.312667
#
#      band_gap_mean  band_gap_std
# 0             5.72         0.004
# 1             5.72         0.004
# 2             5.72         0.004
# 3             5.72         0.004
# 4             5.72         0.004
# ..             ...           ...
# 525           2.07         0.026
# 526           2.07         0.026
# 527           2.07         0.026
# 528           2.07         0.026
# 529           2.07         0.026
#
# [530 rows x 903 columns]

# %%
from sklearn.linear_model import *
import sklearn.ensemble
import sklearn.neighbors
import sklearn.neural_network
from xgboost import XGBRegressor
#ExtraTreesRegressor
#GradientBoostingRegressor
#StackingRegressor

models = [(sklearn.ensemble.RandomForestRegressor(),
           {
               'boostrap': [True, False],
               'max_depth':[10,20,50],
               'max_features':['auto','sqrt'],
               'min_samples_split': [2, 3, 4, 5],
               'min_samples_leaf': [1, 2, 3]
           },
           sklearn.neighbors.KNeighborsRegressor(),
           {
               'n_neighbors': [5, 10, 15, 20],
                'weights': ['uniform', 'distance']
           },
           XGBRegressor(),
           {
               'n_estimators': [100,300],
               'learning_rate': [0.1,0.05],
               'subsample': [0.75],
               'colsample_bytree': [1],
               'max_depth': [3,4,5],
               'gamma': [0]
           },
           
          )
        ]

models_ = [sklearn.ensemble.RandomForestRegressor(),
           sklearn.ensemble.AdaBoostRegressor(),
           sklearn.ensemble.BaggingRegressor(),
           sklearn.ensemble.ExtraTreesRegressor(),
           sklearn.ensemble.HistGradientBoostingRegressor(),#  LightGBM
           sklearn.ensemble.ExtraTreesRegressor(),
           XGBRegressor(n_jobs = -1),
           sklearn.neighbors.KNeighborsRegressor(),
           sklearn.linear_model.ARDRegression(),
           sklearn.linear_model.ElasticNetCV(),             #Include Cross-Validation
           sklearn.linear_model.BayesianRidge(),
           sklearn.linear_model.SGDRegressor(max_iter=5000, tol=1e-3),
           sklearn.linear_model.LassoCV(),
           sklearn.linear_model.ElasticNet(),
           sklearn.neural_network.MLPRegressor()]
           #sklearn.neural_network.MLPRegressor(hidden_layer_sizes=(64,64,64), max_iter=500)]

# %%
import sklearn.model_selection
import sklearn.metrics
import json
import joblib

class Encoder(json.JSONEncoder):
    def default(self, obj): # pylint: disable=E0202
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, sklearn.tree.DecisionTreeClassifier):
            return obj.__class__.__name__
        else:
            return super(Encoder, self).default(obj)
        
class Splitter:
    def __init__(self,data, label = "band_gap_mean"):
        self.data  = data
        self.features = self.data.iloc[:,:-2]
        self.label = self.data[label]
        self.data = None     
    def split(self, location):
        self.features_train, self.features_test, self.label_train, self.label_test = sklearn.model_selection.train_test_split(self.features, self.label, test_size=0.33 )
        self.features_train.to_csv(location + 'features_train.csv', index = False)
        self.features_test.to_csv(location + 'features_test.csv', index = False, header = True)
        self.label_train.to_csv(location + 'label_train.csv', index = False)
        self.label_test.to_csv(location + 'label_test.csv', index = False, header = True)
        
class EvModelDev:
    def __init__(self, features_train, label_train, models):
        self.features_train = pd.read_csv(features_train)
        self.label_train = pd.read_csv(label_train)
        self.train = np.concatenate([self.features_train, self.label_train], axis=1) #to speed up the training we convert it to numpy
        self.models = models
    def grid_search(self,report_location, n_jobs=-1, models = models, scoring = 'geometric_mean' ):
        self.gs_scores = {}
        for model in models:
            nomdel_name = model[0].__class__.__name__
            estimator = model[0]
            grid = model[1]
            features = self.train[:,:-1]
            label = self.train[:,-1]
            if scoring == 'neg_mean_absolute_percentage_error':
                scorer = sklearn.metrics.mean_absolute_percentage_error
            grid_search = sklearn.model_selection.RandomizedSearchCV(
            estimator=estimator,
            param_distributions=grid,
            scoring=scorer,
            n_jobs=n_jobs,
            verbose=2,
            random_state=11,
            return_train_score=True,
            cv=3
            )
            grid_search.fit(features, label)
            self.gs_scores[model_name] = [grid_search.cv_results_, grid_search.best_params_, grid_search.best_score_]
            with open(report_location + 'grid_search_'+ model_name + '.json', 'w', encoding='utf-8') as json_file:
                     json.dump(self.gs_scores[model_name], json_file, indent=2, ensure_ascii=False, cls=Encoder)
    def train_cv(self, models_locatiion, report_location, n_jobs=-1):
        self.cv_scores={}
        features = self.train[:,:-1]
        label = self.train[:,-1]
        for model in self.models:
            model_name = model.__class__.__name__
            estimator = model
            cv_scores = sklearn.model_selection.cross_validate(
                estimator=estimator,
                X=features,
                y=label,
                cv=5,
                n_jobs=n_jobs,
                scoring={
                    'mean_absolute_error':'neg_mean_absolute_error',
                    'mean_absolute_percentage_error':'neg_mean_absolute_percentage_error',
                    'mean_squared_error':'neg_mean_squared_error',
                    'r2':'r2',
                    'explained_variance':'explained_variance'
                },                                                   #sklearn.metrics.SCORERS.keys()
                verbose=2,
                return_train_score=True
            )
            self.cv_scores[model_name] = cv_scores
            with open(report_location + 'cross_val_' + model_name + '.json', 'w', encoding = 'utf-8') as json_file:
                json.dump(self.cv_scores[model_name], json_file, indent=2, ensure_ascii=False, cls=Encoder)
    def train_direct(self, model_location):
        for estimator in self.models:
            model_name = estimator.__class__.__name__
            print(model_name)
            features = self.train[:,:-1]
            label  = self.train[:,-1]
            estimator.fit(features, label)
            print(estimator.score(features,label))
            joblib.dump(estimator, model_location + model_name + ".joblib")
    def predict_direct(self, models_location, features_test, label_test):
        features_test = pd.read_csv(features_test)
        label_test = pd.read_csv(label_test)
        for model in self.models:
            model_name = model.__class__.__name__
            estimator = joblib.load(models_location + model_name + '.joblib')
            try:
                bg_predict = estimator.predict(features_test.values)
            except:
                bg_predict = np.zeros(len(label_test),1)
            results = np.column_stack([label_test,bg_predict])
            np.savetxt(models_location + model_name + '_predictions.txt',results)

class EvalModel:
    def __init__(self, models):
        self.models = models
    def performance(self, models_location):
        for model in self.models:    #se debe crear un json que guarde todos los datos
            model_name = model.__class__.__name__
            results = np.loadtxt(models_location+ model_name + '_predictions.txt')
            mae = sklearn.metrics.mean_absolute_error(results[:,0],results[:,1].round(2))  #TWO decimal digits
            mape = sklearn.metrics.mean_absolute_percentage_error(results[:,0],results[:,1].round(2))
            mse = sklearn.metrics.mean_squared_error(results[:,0],results[:,1].round(2))
            r2 = sklearn.metrics.r2_score(results[:,0],results[:,1].round(2))
            print('Model: ', model_name)
            print('MAE: ', mae)
            print('\nMAPE: ', mape)
            print('\nMSE: ', mse)
            print('\nR2: ', r2)

# %%
s = Splitter(df)
s.split("/kaggle/working/")

# %%
m = EvModelDev("/kaggle/working/features_train.csv", "/kaggle/working/label_train.csv", models_)
m.train_cv("/kaggle/working/", "/kaggle/working/", n_jobs=-1)
m.train_direct("/kaggle/working/")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   25.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    8.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   12.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    8.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   11.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    7.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.059e-02, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.769e-02, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.875e-02, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.118e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.098e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.827e-02, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.500e-02, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.279e-02, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.207e-02, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.559e-02, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.640e-02, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.663e-02, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.957e-02, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.127e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.384e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.400e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.538e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.867e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.008e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.231e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.087e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.606e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.781e-02, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.705e-02, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.344e-01, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.571e-01, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.826e-01, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.007e-01, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.978e-01, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.164e-01, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.143e-01, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.902e-01, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.592e-01, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.039e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.166e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.909e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.128e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.225e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.418e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.413e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.410e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.368e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.336e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.068e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.169e-02, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.051e-02, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.334e-02, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.389e-02, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.174e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.870e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.098e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.696e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.960e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.128e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.290e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.585e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.699e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.371e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.048e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.640e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.564e-01, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.100e+00, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.178e+00, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.284e+00, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.478e+00, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.366e+00, tolerance: 9.835e-03
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.083e-02, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.096e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.778e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.059e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.177e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.375e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.504e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.841e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.024e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.420e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.094e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.614e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.701e-01, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.450e+00, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.879e+00, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.843e+00, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.984e+00, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.116e+00, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.272e+00, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.171e+00, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.196e+00, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.011e+00, tolerance: 1.122e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.805e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.129e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.883e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.246e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.745e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.465e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.892e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.708e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.037e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.101e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.415e-01, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.140e+00, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.223e+00, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.525e+00, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.686e+00, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.938e+00, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.187e+00, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.388e+00, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.576e+00, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.450e+00, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.643e+00, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.363e+00, tolerance: 1.202e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.934e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.475e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.407e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.770e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.064e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.328e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.557e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.628e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.995e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.310e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.033e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.784e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.801e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.030e+00, tolerance: 1.058e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.085e+00, tolerance: 1.058e-02
# ...
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.703e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.815e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.714e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.736e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.174e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.599e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.911e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.104e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.207e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.906e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.607e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.902e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.247e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.524e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.012e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.569e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.687e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.414e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.521e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.637e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.702e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.586e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.348e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.915e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.434e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.613e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.652e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.654e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.873e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.630e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.271e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.824e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.349e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.277e+00, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.005e+01, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.081e+01, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.137e+01, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.179e+01, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.208e+01, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.220e+01, tolerance: 1.793e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.140e+01, tolerance: 2.094e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# 0.6057449660033507
# ElasticNet
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.154e+01, tolerance: 2.094e-02
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# 0.6045589680115622
# MLPRegressor
# -159.51331562110232
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,

# %%
m.predict_direct("/kaggle/working/","/kaggle/working/features_test.csv","/kaggle/working/label_test.csv")

# %%
#Data with three decimal digits
#MAE:  0.057852893081761246
#MSE:  0.021104927610691843

e = EvalModel(models_)
e.performance("/kaggle/working/")
# Out:
# Model:  RandomForestRegressor
# MAE:  0.05011428571428574
#
# MAPE:  0.02168161359309169
#
# MSE:  0.004893142857142862
#
# R2:  0.9934539048180178
# Model:  AdaBoostRegressor
# MAE:  0.0705714285714286
#
# MAPE:  0.031556322602462133
#
# MSE:  0.010615428571428583
#
# R2:  0.9857985740750107
# Model:  BaggingRegressor
# MAE:  0.052914285714285726
#
# MAPE:  0.022368151448581505
#
# MSE:  0.005875428571428573
#
# R2:  0.9921397932195327
# Model:  ExtraTreesRegressor
# MAE:  0.04331428571428572
#
# MAPE:  0.01908081975428727
#
# MSE:  0.003403428571428572
#
# R2:  0.9954468594062962
# Model:  HistGradientBoostingRegressor
# MAE:  0.07200000000000002
#
# MAPE:  0.02922387715035348
#
# MSE:  0.02349714285714287
#
# R2:  0.9685652885807418
# Model:  ExtraTreesRegressor
# MAE:  0.04331428571428572
#
# MAPE:  0.01908081975428727
#
# MSE:  0.003403428571428572
#
# R2:  0.9954468594062962
# Model:  XGBRegressor
# MAE:  0.06354285714285714
#
# MAPE:  0.02609038281235525
#
# MSE:  0.02025714285714287
#
# R2:  0.9728997928061113
# Model:  KNeighborsRegressor
# MAE:  0.0941714285714286
#
# MAPE:  0.03540899368036319
#
# MSE:  0.025697142857142866
#
# R2:  0.965622106699318
# Model:  ARDRegression
# MAE:  0.6332571428571429
#
# MAPE:  0.2507347078454333
#
# MSE:  1.7795417142857144
#
# R2:  -1.3806886048743006
# Model:  ElasticNetCV
# MAE:  0.4309142857142857
#
# MAPE:  0.16618769736792494
#
# MSE:  0.42583485714285707
#
# R2:  0.43031389271748877
# Model:  BayesianRidge
# MAE:  0.35845714285714286
#
# MAPE:  0.1403325197740588
#
# MSE:  0.46756857142857144
#
# R2:  0.3744821146582934
# Model:  SGDRegressor
# MAE:  6.840218071485056e+16
#
# MAPE:  3.175711245557918e+16
#
# MSE:  7.05484542180828e+33
#
# R2:  -9.438042373505169e+33
# Model:  LassoCV
# MAE:  0.4299428571428572
#
# MAPE:  0.16562550086724084
#
# MSE:  0.422006857142857
#
# R2:  0.43543502919116617
# Model:  ElasticNet
# MAE:  0.42171428571428576
#
# MAPE:  0.16116633366259778
#
# MSE:  0.4043542857142856
#
# R2:  0.4590508148225796
# Model:  MLPRegressor
# MAE:  7.1932
#
# MAPE:  3.0807476577719224
#
# MSE:  191.9547937142857
#
# R2:  -255.7990322328717

# %%
#Resultados
np.loadtxt('/kaggle/working/RandomForestRegressor_predictions.txt').round(2)
# Out:
# array([[5.01, 4.95],
#        [2.26, 2.24],
#        [1.99, 2.  ],
#        [1.94, 1.97],
#        [1.92, 2.01],
#        [2.06, 2.  ],
#        [2.06, 2.1 ],
#        [4.84, 4.86],
#        [2.15, 2.13],
#        [3.3 , 3.3 ],
#        [2.24, 2.17],
#        [2.24, 2.17],
#        [2.08, 1.99],
#        [5.01, 5.01],
#        [2.02, 2.03],
#        [2.01, 2.01],
#        [2.11, 2.12],
#        [2.  , 2.04],
#        [1.97, 1.98],
#        [5.01, 5.03],
#        [2.47, 2.32],
#        [2.11, 2.  ],
#        [2.03, 2.03],
#        [2.21, 2.21],
#        [5.01, 5.02],
#        [1.97, 2.  ],
#        [2.07, 2.14],
#        [1.98, 2.  ],
#        [2.24, 2.22],
#        [2.01, 2.  ],
#        [1.84, 1.96],
#        [3.31, 3.3 ],
#        [2.07, 2.13],
#        [2.05, 2.08],
#        [2.11, 2.01],
#        [2.02, 2.06],
#        [1.97, 1.98],
#        [3.35, 3.31],
#        [2.08, 1.99],
#        [2.09, 2.07],
#        [2.11, 2.01],
#        [2.15, 2.14],
#        [1.92, 2.  ],
#        [2.22, 2.11],
#        [2.24, 2.15],
#        [1.99, 2.  ],
#        [5.72, 5.46],
#        [2.06, 2.02],
#        [2.06, 2.1 ],
#        [4.83, 4.9 ],
#        [2.03, 2.1 ],
#        [2.03, 2.01],
#        [3.35, 3.32],
#        [1.97, 1.98],
#        [2.24, 2.17],
#        [2.04, 2.12],
#        [1.99, 2.02],
#        [2.03, 2.01],
#        [3.3 , 3.29],
#        [3.38, 3.32],
#        [4.83, 4.97],
#        [2.25, 2.19],
#        [1.92, 1.99],
#        [2.07, 2.11],
#        [2.01, 2.02],
#        [3.23, 3.26],
#        [2.26, 2.18],
#        [2.  , 2.05],
#        [2.07, 2.12],
#        [5.72, 5.43],
#        [1.86, 1.91],
#        [2.05, 2.11],
#        [2.02, 2.06],
#        [1.98, 1.96],
#        [2.02, 2.01],
#        [2.11, 2.1 ],
#        [4.83, 4.82],
#        [2.15, 2.13],
#        [2.15, 2.11],
#        [2.16, 2.12],
#        [2.02, 2.1 ],
#        [2.27, 2.12],
#        [3.31, 3.31],
#        [2.07, 2.19],
#        [1.94, 1.99],
#        [2.11, 2.14],
#        [1.97, 1.97],
#        [2.03, 2.01],
#        [2.03, 2.03],
#        [1.99, 2.  ],
#        [1.97, 1.99],
#        [2.24, 2.15],
#        [1.84, 1.98],
#        [3.38, 3.33],
#        [2.03, 2.17],
#        [2.14, 2.19],
#        [2.08, 1.94],
#        [4.98, 4.94],
#        [2.08, 2.13],
#        [2.14, 2.1 ],
#        [2.12, 2.15],
#        [2.02, 2.02],
#        [1.97, 1.97],
#        [2.01, 2.01],
#        [2.02, 2.04],
#        [2.06, 2.03],
#        [5.06, 5.37],
#        [2.07, 2.14],
#        [2.26, 2.2 ],
#        [2.12, 2.06],
#        [2.12, 2.07],
#        [2.04, 2.05],
#        [2.01, 2.01],
#        [1.94, 1.99],
#        [3.3 , 3.32],
#        [2.04, 2.13],
#        [3.31, 3.31],
#        [2.04, 2.06],
#        [2.26, 2.18],
#        [2.08, 1.96],
#        [2.22, 2.11],
#        [2.26, 2.2 ],
#        [2.06, 2.11],
#        [2.1 , 2.2 ],
#        [3.3 , 3.3 ],
#        [2.  , 2.  ],
#        [1.94, 2.01],
#        [1.98, 1.96],
#        [5.21, 5.21],
#        [1.92, 1.99],
#        [1.98, 2.01],
#        [2.16, 2.12],
#        [2.01, 2.01],
#        [2.06, 2.02],
#        [2.04, 2.09],
#        [2.07, 2.05],
#        [2.08, 2.13],
#        [2.07, 2.03],
#        [2.11, 2.01],
#        [2.14, 2.17],
#        [1.98, 1.98],
#        [2.11, 2.  ],
#        [2.22, 2.05],
#        [1.98, 1.99],
#        [1.98, 1.97],
#        [2.04, 2.  ],
#        [3.3 , 3.33],
#        [2.24, 2.17],
#        [2.04, 1.97],
#        [2.  , 2.05],
#        [1.97, 1.96],
#        [1.92, 2.  ],
#        [2.04, 1.95],
#        [2.03, 2.05],
#        [2.1 , 2.16],
#        [2.08, 2.12],
#        [2.07, 2.12],
#        [1.94, 1.98],
#        [1.98, 2.  ],
#        [2.02, 2.04],
#        [2.02, 2.  ],
#        [2.06, 2.03],
#        [2.06, 2.03],
#        [1.99, 2.01],
#        [2.  , 2.02],
#        [2.  , 2.04],
#        [2.05, 2.08],
#        [2.47, 2.36],
#        [1.94, 1.99],
#        [2.05, 2.09],
#        [1.97, 1.98],
#        [5.01, 4.97],
#        [2.04, 1.94],
#        [1.92, 2.01],
#        [2.08, 1.99]])
